# %%
import nltk

from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

# %%
paragraph="""I have a book's inside inside in my shell which is next to my bed, Could you please get my Books for me."""

# %%
sentence=nltk.sent_tokenize(paragraph)
sentence[:6]
# Out:
# ["I have a book's inside inside in my shell which is next to my bed, Could you please get my Books for me."]

# %%
#Stemmimng
stemmer=PorterStemmer()

# %%
for i in range(len(sentence)):
    words=nltk.word_tokenize(sentence[i])
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentence=" ".join(words)

# %%
sentence
# Out:
# "I book 's insid insid shell next bed , could pleas get book ."

# %%
#Lemmatizer

from nltk.stem import WordNetLemmatizer

# %%
lemmatize=WordNetLemmatizer()

# %%
paragraph="""Hello, the world is going tobe end in December. Danger ahead,becarefull"""

# %%
sentence=nltk.sent_tokenize(paragraph)

# %%
sentence
# Out:
# ['Hello, the world is going tobe end in December.', 'Danger ahead,becarefull']

# %%
for i in range(len(sentence)):
    corpus=[]
    words=nltk.word_tokenize(sentence[i])
    words=[lemmatize.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    senence=' '.join(words)
    corpus.append(sentence)

# %%
corpus
# Out:
# [['Hello, the world is going tobe end in December.',
#   'Danger ahead,becarefull']]
